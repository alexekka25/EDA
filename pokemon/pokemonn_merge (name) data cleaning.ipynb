# %%
import numpy as np ,pandas as pd,json

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv(r"D:\data analyst\datasets\fifa data\pokemon.csv")
df2=pd.read_json(r"C:\Users\ALEX\Downloads\pokedex.json")

# %%
df2
# Out:
#                                                pokemon
# 0    {'id': 1, 'num': '001', 'name': 'Bulbasaur', '...
# 1    {'id': 2, 'num': '002', 'name': 'Ivysaur', 'im...
# 2    {'id': 3, 'num': '003', 'name': 'Venusaur', 'i...
# 3    {'id': 4, 'num': '004', 'name': 'Charmander', ...
# 4    {'id': 5, 'num': '005', 'name': 'Charmeleon', ...
# ..                                                 ...
# 146  {'id': 147, 'num': '147', 'name': 'Dratini', '...
# 147  {'id': 148, 'num': '148', 'name': 'Dragonair',...
# 148  {'id': 149, 'num': '149', 'name': 'Dragonite',...
# 149  {'id': 150, 'num': '150', 'name': 'Mewtwo', 'i...
# 150  {'id': 151, 'num': '151', 'name': 'Mew', 'img'...
#
# [151 rows x 1 columns]

# %%
df1.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
try:
    pokeDexJsonStr = open(r'C:\Users\ALEX\Downloads\pokedex.json')
except (FileNotFoundError):
    print('pleae check if the file name is correct or if the file exists in first place')
else:
    pokeDexJson = json.load(pokeDexJsonStr)
    print(type(pokeDexJson))
# Out:
# <class 'dict'>

# %%
pokeDex = pd.json_normalize(pokeDexJson,record_path = ['pokemon'])
pokeDex.head()
# Out:
#    id  num        name                                               img  \
# 0   1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#               type  height    weight             candy  candy_count  \
# 0  [Grass, Poison]  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  [Grass, Poison]  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  [Grass, Poison]  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           [Fire]  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           [Fire]  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# ...

# %%
pokeDex.head()
# Out:
#    id  num        name                                               img  \
# 0   1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#               type  height    weight             candy  candy_count  \
# 0  [Grass, Poison]  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  [Grass, Poison]  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  [Grass, Poison]  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           [Fire]  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           [Fire]  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# ...

# %%
pokeDex.columns
# Out:
# Index(['id', 'num', 'name', 'img', 'type', 'height', 'weight', 'candy',
#        'candy_count', 'egg', 'spawn_chance', 'avg_spawns', 'spawn_time',
#        'multipliers', 'weaknesses', 'next_evolution', 'prev_evolution'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %% [markdown]
# # Merging the data two data set

# %%
merged_df = pd.merge(pokeDex, df1, on=['name'], how='right')
merged_df
# Out:
#       id  num        name                                               img  \
# 0    1.0  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1    2.0  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    3.0  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3    4.0  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4    5.0  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# ..   ...  ...         ...                                               ...
# 796  NaN  NaN  Celesteela                                               NaN
# 797  NaN  NaN     Kartana                                               NaN
# 798  NaN  NaN    Guzzlord                                               NaN
# 799  NaN  NaN    Necrozma                                               NaN
# 800  NaN  NaN    Magearna                                               NaN
#
# ...

# %%
merged_df.head(35)
# Out:
#       id  num        name                                               img  \
# 0    1.0  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1    2.0  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    3.0  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3    4.0  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4    5.0  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5    6.0  006   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6    7.0  007    Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7    8.0  008   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# 8    9.0  009   Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 9   10.0  010    Caterpie  http://www.serebii.net/pokemongo/pokemon/010.png
# 10  11.0  011     Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# ...

# %%
merged_df.isnull().sum()
# Out:
# id                   652
# num                  652
# name                   0
# img                  652
# type                 652
# height               652
# weight               652
# candy                652
# candy_count          733
# egg                  652
# spawn_chance         652
# avg_spawns           652
# spawn_time           652
# multipliers          733
# weaknesses           652
# next_evolution       733
# prev_evolution       729
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# ...

# %% [markdown]
#  # droping the columns

# %%
columns_to_drop = ['id','num','img','type','candy','candy_count','egg','spawn_time','avg_spawns','multipliers','weaknesses','percentage_male','next_evolution','prev_evolution','weight_kg','pokedex_number']

#Drop the specified columns
df = merged_df.drop(columns=columns_to_drop)

print(df)
# Out:
#            name  height    weight  spawn_chance                    abilities  \
# 0     Bulbasaur  0.71 m    6.9 kg         0.690  ['Overgrow', 'Chlorophyll']
# 1       Ivysaur  0.99 m   13.0 kg         0.042  ['Overgrow', 'Chlorophyll']
# 2      Venusaur  2.01 m  100.0 kg         0.017  ['Overgrow', 'Chlorophyll']
# 3    Charmander  0.61 m    8.5 kg         0.253     ['Blaze', 'Solar Power']
# 4    Charmeleon  1.09 m   19.0 kg         0.012     ['Blaze', 'Solar Power']
# ..          ...     ...       ...           ...                          ...
# 796  Celesteela     NaN       NaN           NaN              ['Beast Boost']
# 797     Kartana     NaN       NaN           NaN              ['Beast Boost']
# 798    Guzzlord     NaN       NaN           NaN              ['Beast Boost']
# 799    Necrozma     NaN       NaN           NaN              ['Prism Armor']
# 800    Magearna     NaN       NaN           NaN               ['Soul-Heart']
#
# ...

# %%
df
# Out:
#            name  height    weight  spawn_chance                    abilities  \
# 0     Bulbasaur  0.71 m    6.9 kg         0.690  ['Overgrow', 'Chlorophyll']
# 1       Ivysaur  0.99 m   13.0 kg         0.042  ['Overgrow', 'Chlorophyll']
# 2      Venusaur  2.01 m  100.0 kg         0.017  ['Overgrow', 'Chlorophyll']
# 3    Charmander  0.61 m    8.5 kg         0.253     ['Blaze', 'Solar Power']
# 4    Charmeleon  1.09 m   19.0 kg         0.012     ['Blaze', 'Solar Power']
# ..          ...     ...       ...           ...                          ...
# 796  Celesteela     NaN       NaN           NaN              ['Beast Boost']
# 797     Kartana     NaN       NaN           NaN              ['Beast Boost']
# 798    Guzzlord     NaN       NaN           NaN              ['Beast Boost']
# 799    Necrozma     NaN       NaN           NaN              ['Prism Armor']
# 800    Magearna     NaN       NaN           NaN               ['Soul-Heart']
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 2360

# %%
df.iloc[147:157]
# Out:
#            name  height    weight  spawn_chance  \
# 147   Dragonair  3.99 m   16.5 kg        0.0200
# 148   Dragonite  2.21 m  210.0 kg        0.0011
# 149      Mewtwo  2.01 m  122.0 kg        0.0000
# 150         Mew  0.41 m    4.0 kg        0.0000
# 151   Chikorita     NaN       NaN           NaN
# 152     Bayleef     NaN       NaN           NaN
# 153    Meganium     NaN       NaN           NaN
# 154   Cyndaquil     NaN       NaN           NaN
# 155     Quilava     NaN       NaN           NaN
# 156  Typhlosion     NaN       NaN           NaN
#
#                          abilities  against_bug  against_dark  against_dragon  \
# 147  ['Shed Skin', 'Marvel Scale']          1.0           1.0             2.0
# 148  ['Inner Focus', 'Multiscale']          0.5           1.0             2.0
# 149        ['Pressure', 'Unnerve']          2.0           2.0             1.0
# 150                ['Synchronize']          2.0           2.0             1.0
# ...

# %% [markdown]
# # droping rows

# %%
df.drop(df.index[151:801], axis=0, inplace=True)

# %% [markdown]
# # `--------------------`

# %% [markdown]
# # `---------------`

# %%
df.head()
# Out:
#          name  height    weight  spawn_chance                    abilities  \
# 0   Bulbasaur  0.71 m    6.9 kg         0.690  ['Overgrow', 'Chlorophyll']
# 1     Ivysaur  0.99 m   13.0 kg         0.042  ['Overgrow', 'Chlorophyll']
# 2    Venusaur  2.01 m  100.0 kg         0.017  ['Overgrow', 'Chlorophyll']
# 3  Charmander  0.61 m    8.5 kg         0.253     ['Blaze', 'Solar Power']
# 4  Charmeleon  1.09 m   19.0 kg         0.012     ['Blaze', 'Solar Power']
#
#    against_bug  against_dark  against_dragon  against_electric  against_fairy  \
# 0          1.0           1.0             1.0               0.5            0.5
# 1          1.0           1.0             1.0               0.5            0.5
# 2          1.0           1.0             1.0               0.5            0.5
# 3          0.5           1.0             1.0               1.0            0.5
# 4          0.5           1.0             1.0               1.0            0.5
#
# ...

# %% [markdown]
# # Imputing values

# %% [markdown]
# ### 1. Height

# %%
df['height']=df['height'].str.replace('m',' ')

# %%
df['height']=df['height'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               151 non-null    object
#  1   height             149 non-null    float64
#  2   weight             149 non-null    object
#  3   spawn_chance       149 non-null    float64
#  4   abilities          151 non-null    object
#  5   against_bug        151 non-null    float64
#  6   against_dark       151 non-null    float64
#  7   against_dragon     151 non-null    float64
#  8   against_electric   151 non-null    float64
#  9   against_fairy      151 non-null    float64
#  10  against_fight      151 non-null    float64
#  11  against_fire       151 non-null    float64
#  12  against_flying     151 non-null    float64
#  13  against_ghost      151 non-null    float64
#  14  against_grass      151 non-null    float64
# ...

# %%
df
# Out:
#            name  height    weight  spawn_chance  \
# 0     Bulbasaur    0.71    6.9 kg        0.6900
# 1       Ivysaur    0.99   13.0 kg        0.0420
# 2      Venusaur    2.01  100.0 kg        0.0170
# 3    Charmander    0.61    8.5 kg        0.2530
# 4    Charmeleon    1.09   19.0 kg        0.0120
# ..          ...     ...       ...           ...
# 146     Dratini    1.80    3.3 kg        0.3000
# 147   Dragonair    3.99   16.5 kg        0.0200
# 148   Dragonite    2.21  210.0 kg        0.0011
# 149      Mewtwo    2.01  122.0 kg        0.0000
# 150         Mew    0.41    4.0 kg        0.0000
#
#                          abilities  against_bug  against_dark  against_dragon  \
# 0      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# ...

# %%
df["height"]=df["height"].fillna(df["height"].mean())

# %% [markdown]
# ### 2.Weight

# %%
df['weight']=df['weight'].str.replace('kg',' ')

# %%
df["weight"]=df["weight"].astype(float)

# %%
df['weight']=df['weight'].fillna(df['weight'].mean())

# %% [markdown]
# ###  3.spawn_chance

# %%
df[df['spawn_chance'].isnull()]
# Out:
#         name    height     weight  spawn_chance  \
# 28  Nidoran♀  1.203691  46.461074           NaN
# 31  Nidoran♂  1.203691  46.461074           NaN
#
#                                 abilities  against_bug  against_dark  \
# 28  ['Poison Point', 'Rivalry', 'Hustle']          0.5           1.0
# 31  ['Poison Point', 'Rivalry', 'Hustle']          0.5           1.0
#
#     against_dragon  against_electric  against_fairy  ...  height_m  hp  \
# 28             1.0               1.0            0.5  ...       0.4  55
# 31             1.0               1.0            0.5  ...       0.5  46
#
#     japanese_name  sp_attack  sp_defense  speed   type1  type2  generation  \
# 28  Nidoran?ニドラン♀         40          40     41  poison    NaN           1
# 31  Nidoran?ニドラン♂         40          40     50  poison    NaN           1
#
#     is_legendary
# 28             0
# 31             0
#
# [2 rows x 41 columns]

# %% [markdown]
# ### 4.adding specific values to specific row

# %%
row_index = 28  # Replace with the index of the row where you want to replace NaN
column_name = "spawn_chance"

if pd.isna(df.loc[row_index, column_name]):
    df.at[row_index, column_name] = 1.31

# %%
row_index = 31  # Replace with the index of the row where you want to replace NaN
column_name = "spawn_chance"

if pd.isna(df.loc[row_index, column_name]):
    df.at[row_index, column_name] = 1.38

# %%
df[df['spawn_chance'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, height, weight, spawn_chance, abilities, against_bug, against_dark, against_dragon, against_electric, against_fairy, against_fight, against_fire, against_flying, against_ghost, against_grass, against_ground, against_ice, against_normal, against_poison, against_psychic, against_rock, against_steel, against_water, attack, base_egg_steps, base_happiness, base_total, capture_rate, classfication, defense, experience_growth, height_m, hp, japanese_name, sp_attack, sp_defense, speed, type1, type2, generation, is_legendary]
# Index: []
#
# [0 rows x 41 columns]

# %%
df.isnull().sum()
# Out:
# name                  0
# height                0
# weight                0
# spawn_chance          0
# abilities             0
# against_bug           0
# against_dark          0
# against_dragon        0
# against_electric      0
# against_fairy         0
# against_fight         0
# against_fire          0
# against_flying        0
# against_ghost         0
# against_grass         0
# against_ground        0
# against_ice           0
# against_normal        0
# against_poison        0
# against_psychic       0
# against_rock          0
# against_steel         0
# against_water         0
# attack                0
# base_egg_steps        0
# base_happiness        0
# base_total            0
# capture_rate          0
# classfication         0
# defense               0
# experience_growth     0
# height_m             18
# hp                    0
# japanese_name         0
# sp_attack             0
# sp_defense            0
# speed                 0
# type1                 0
# ...

# %% [markdown]
# # Saving cleaned data

# %%
#df.to_csv('cleaned_dataset.csv', index=False)
