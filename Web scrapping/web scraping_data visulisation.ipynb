# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfplayer = pd.read_csv(r"D:\data analyst\Web scraping\2024 top 100.csv")

# %%
dfmarket = pd.read_csv(r"D:\data analyst\Web scraping\player_value.csv")

# %%
dfclubs = pd.read_csv(r"D:\data analyst\Web scraping\top clubs.csv")

# %%
dfplayer.head()
# Out:
#    rank                               Player   OVA   POT   ATT   SKI   MOV  \
# 0   1.0  Kylian MbappéST|Paris Saint-Germain  91.0  94.0  82.0  81.0  92.0
# 1   2.0     Erling HaalandST|Manchester City  91.0  94.0  76.0  70.0  82.0
# 2   3.0    Kevin De BruyneCM|Manchester City  91.0  91.0  82.0  89.0  79.0
# 3   4.0       Lionel MessiCAM|Inter Miami CF  90.0  90.0  85.0  93.0  88.0
# 4   5.0           Karim BenzemaCF|Al Ittihad  90.0  90.0  87.0  82.0  80.0
#
#     POW   MEN   DEF    GK  STATS
# 0  82.0  74.0  31.0   8.0  2,204
# 1  86.0  75.0  42.0  10.0  2,156
# 2  82.0  83.0  62.0  11.0  2,317
# 3  77.0  74.0  26.0  11.0  2,166
# 4  82.0  76.0  28.0   8.0  2,152

# %%
dfmarket.head()
# Out:
#             Player          Position  Age Nationality1 Nationality2  \
# 0   Erling Haaland    Centre-Forward   22       Norway          NaN
# 1    Kylian Mbappé    Centre-Forward   24       France     Cameroon
# 2  Vinicius Junior       Left Winger   22       Brazil        Spain
# 3  Jude Bellingham  Central Midfield   20      England          NaN
# 4      Bukayo Saka      Right Winger   21      England      Nigeria
#
#                   Club  MarketValue(m)
# 0      Manchester City             180
# 1  Paris Saint-Germain             180
# 2          Real Madrid             150
# 3          Real Madrid             120
# 4           Arsenal FC             120

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Joint plot with yellow color shades
sns.set(style="whitegrid")  
sns.jointplot(x='Age', y='MarketValue(m)', data=dfmarket, kind='scatter',
              marginal_kws=dict(bins=25, fill=False),
              joint_kws=dict(marker="o", facecolors="yellow", edgecolors="black", alpha=0.7))

plt.suptitle('Joint Plot: Age vs. Market Value', y=1.02)
plt.show()
# Out:
# C:\Users\ALEX\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ALEX\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(dfmarket[['Age', 'MarketValue(m)']])
plt.suptitle('Pair Plot: Age vs. Market Value', y=1.02)
plt.show()
# Out:
# C:\Users\ALEX\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ALEX\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ALEX\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set(style="whitegrid")  # Optional: Set the background style
sns.regplot(x='Age', y='MarketValue(m)', data=dfmarket, scatter_kws={'alpha': 0.5}, line_kws={'color': 'yellow'})

plt.title('Regression Plot: Age vs. Market Value')
plt.show()

# %%
dfclubs['clubs'].str.split(" ")
# Out:
# 0         [Manchester, CityEnglish, Premier, League]
# 1         [Real, Madrid, CFSpain, Primera, Division]
# 2        [FC, Bayern, MünchenGerman, 1., Bundesliga]
# 3            [FC, BarcelonaSpain, Primera, Division]
# 4                [LiverpoolEnglish, Premier, League]
#                            ...
# 682            [Chennaiyin, FCIndian, Super, League]
# 683    [Finn, HarpsRep., Ireland, Premier, Division]
# 684          [Guangzhou, CityChinese, Super, League]
# 685       [UCD, AFCRep., Ireland, Premier, Division]
# 686                [Hebei, FCChinese, Super, League]
# Name: clubs, Length: 687, dtype: object

# %%
dfplayer = dfplayer.dropna(how='all')

dfplayer = dfplayer.reset_index(drop=True)

print(dfplayer)
# Out:
#      rank                               Player   OVA   POT   ATT   SKI   MOV  \
# 0     1.0  Kylian MbappéST|Paris Saint-Germain  91.0  94.0  82.0  81.0  92.0
# 1     2.0     Erling HaalandST|Manchester City  91.0  94.0  76.0  70.0  82.0
# 2     3.0    Kevin De BruyneCM|Manchester City  91.0  91.0  82.0  89.0  79.0
# 3     4.0       Lionel MessiCAM|Inter Miami CF  90.0  90.0  85.0  93.0  88.0
# 4     5.0           Karim BenzemaCF|Al Ittihad  90.0  90.0  87.0  82.0  80.0
# ..    ...                                  ...   ...   ...   ...   ...   ...
# 95   96.0                Paul PogbaCM|Juventus  84.0  84.0  78.0  87.0  69.0
# 96   97.0        CanalesRM|Real Betis Balompié  84.0  84.0  72.0  84.0  83.0
# 97   98.0            F. KessiéCDM|FC Barcelona  84.0  86.0  70.0  70.0  77.0
# 98   99.0                 WevertonGK|Palmeiras  84.0  84.0  21.0  23.0  47.0
# 99  100.0      G. De ArrascaetaCAM|Free Agency  84.0  84.0  76.0  83.0  83.0
#
#      POW   MEN   DEF    GK  STATS
# ...

# %%
dfplayer["club"] = dfplayer["Player"].apply(lambda x: x.split("|")[1])

# %%
dfplayer["Player"] = dfplayer["Player"].str.split("|").str[0]

# %%
column_name_mapping = {
    'OVA': 'Overall',
    'POT': 'Potential',
    'ATT': 'Attacking',
    'SKI': 'Skills',
    'MOV': 'Movement',
    'POW': 'Power',
    'MEN': 'Mentality',
    'DEF': 'Defending',
    'GK': 'Goalkeeping'
}

dfplayer.rename(columns=column_name_mapping, inplace=True)


print(dfplayer)
# Out:
#      rank               Player  Overall  Potential  Attacking  Skills  \
# 0     1.0      Kylian MbappéST     91.0       94.0       82.0    81.0
# 1     2.0     Erling HaalandST     91.0       94.0       76.0    70.0
# 2     3.0    Kevin De BruyneCM     91.0       91.0       82.0    89.0
# 3     4.0      Lionel MessiCAM     90.0       90.0       85.0    93.0
# 4     5.0      Karim BenzemaCF     90.0       90.0       87.0    82.0
# ..    ...                  ...      ...        ...        ...     ...
# 95   96.0         Paul PogbaCM     84.0       84.0       78.0    87.0
# 96   97.0            CanalesRM     84.0       84.0       72.0    84.0
# 97   98.0         F. KessiéCDM     84.0       86.0       70.0    70.0
# 98   99.0           WevertonGK     84.0       84.0       21.0    23.0
# 99  100.0  G. De ArrascaetaCAM     84.0       84.0       76.0    83.0
#
#     Movement  Power  Mentality  Defending  Goalkeeping  STATS  \
# 0       92.0   82.0       74.0       31.0          8.0  2,204
# ...

# %%
dfplayer.columns
# Out:
# Index(['rank', 'Player', 'Overall', 'Potential', 'Attacking', 'Skills',
#        'Movement', 'Power', 'Mentality', 'Defending', 'Goalkeeping', 'STATS',
#        'club'],
#       dtype='object')

# %%
dfplayer.describe()
# Out:
#              rank     Overall   Potential   Attacking     Skills    Movement  \
# count  100.000000  100.000000  100.000000  100.000000  100.00000  100.000000
# mean    50.500000   86.460000   87.910000   64.530000   68.83000   75.260000
# std     29.011492    1.794605    2.558784   21.009596   20.73452   11.058723
# min      1.000000   84.000000   84.000000   15.000000   14.00000   45.000000
# 25%     25.750000   85.000000   86.000000   62.750000   64.00000   69.000000
# 50%     50.500000   86.000000   88.000000   72.000000   77.50000   79.000000
# 75%     75.250000   87.250000   90.000000   77.250000   82.00000   83.000000
# max    100.000000   91.000000   94.000000   87.000000   93.00000   92.000000
#
#             Power   Mentality   Defending  Goalkeeping
# count  100.000000  100.000000  100.000000   100.000000
# mean    71.440000   67.570000   53.600000    23.070000
# std     10.687782   15.472527   26.346947    28.123916
# ...

# %% [markdown]
# # `Problem Statement:`

# %% [markdown]
# ## <font color="#001f3f">**Exploring Trends in Football Player Market Value Across Careers.**</font>

# %% [markdown]
# Analyzing the Intersection of Player Valuation: Leveraging statistical metrics and market values, this study aims to identify undervalued players based on their on-field performance relative to market expectations. Additionally, we investigate the influence of player age and position on their market value. The goal is to provide actionable insights for clubs, scouts, and enthusiasts seeking valuable players and understand the factors impacting market valuations in the soccer industry."

# %% [markdown]
# 1. Exploring Player Market Value Trends with Age
#
# 2. Can we find valuable players who are currently undervalued based on their statistics and market value
#
# 3. Quantifying the Impact of Age and Position on Football Player Market Value.

# %%
from matplotlib.colors import ListedColormap

#Define the hex codes for the custom palette
fyn_palette = ['#E5AF0A', '#BC8901', '#745305','#5F4509', '#E6E6E6',
                '#C8C7C7','#ABA7A8', '#787374', '#50494A']

#Create a ListedColormap using the custom palette
cmap = ListedColormap(fyn_palette)

# %%
fyn_palette = ['#E5AF0A', '#BC8901', '#745305', '#5F4509', '#E6E6E6', '#C8C7C7', '#ABA7A8', '#787374', '#50494A']

# Create a ListedColormap using the custom palette
cmap = ListedColormap(fyn_palette)

# Assuming 'dfplayer' is your DataFrame
top_10_players = dfplayer.nlargest(10, 'Overall')

# Plot using Matplotlib with horizontal bars
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.barh(top_10_players['Player'], top_10_players['Overall'], color=fyn_palette)

# Add color bar legend
sm = plt.cm.ScalarMappable(cmap=cmap)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, pad=0.2)
cbar.set_label('Overall Rating')

ax.set_title('Top 10 Players with Highest Overall Ratings')
ax.set_xlabel('Overall Rating')
ax.set_ylabel('Player Name')

plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
dfmarket['MarketValue(m)'].describe()
# Out:
# count    500.000000
# mean      36.770000
# std       21.760978
# min       18.000000
# 25%       22.000000
# 50%       30.000000
# 75%       40.000000
# max      180.000000
# Name: MarketValue(m), dtype: float64

# %% [markdown]
# # `univariate, bivariate, and multivariate analysis along with visualization`

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.histplot(dfplayer['Overall'], kde=True, color='#E5AF0A')
plt.title('Distribution of Overall Ratings')
plt.xlabel('Overall Rating')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(12, 6))
sns.histplot(dfplayer['Potential'], kde=True, color='#5F4509')
plt.title('Distribution of Potential Ratings')
plt.xlabel('Potential Rating')
plt.ylabel('Frequency')
plt.show()

skills_columns = ['Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending']
plt.figure(figsize=(16, 10))
for i, skill in enumerate(skills_columns, 1):
    plt.subplot(3, 3, i)
    sns.histplot(dfplayer[skill], kde=True)
    plt.title(f'Distribution of {skill}')
    plt.xlabel(skill)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Histogram for Age
plt.figure(figsize=(10, 6))
sns.histplot(dfmarket['Age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Player Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Histogram for MarketValue(m)
plt.figure(figsize=(10, 6))
sns.histplot(dfmarket['MarketValue(m)'], bins=20, kde=True, color='orange')
plt.title('Distribution of Player Market Values')
plt.xlabel('Market Value (m)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 1. Exploring Player Market Value Trends with Age,Position:

# %%
df_analysis = dfmarket[['MarketValue(m)', 'Age', 'Position']]

df_analysis = pd.get_dummies(df_analysis, columns=['Position'], drop_first=True)

correlation_matrix = df_analysis.corr()


# heatmap for correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df_analysis = dfmarket[['MarketValue(m)', 'Age', 'Position']]

df_analysis = pd.get_dummies(df_analysis, columns=['Position'], drop_first=True)

# Scatter plot for Age vs. MarketValue(m)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='MarketValue(m)', data=df_analysis, alpha=0.7)

plt.xticks(range(int(df_analysis['Age'].min()), int(df_analysis['Age'].max()) + 1))

plt.title('Scatter Plot: Age vs. Market Value')
plt.xlabel('Age')
plt.ylabel('Market Value (in millions)')
plt.show()

# %%
top_5_players_high_value = dfmarket.nlargest(5, 'MarketValue(m)')

# Filter for top 3 players with low age
top_3_players_low_age = dfmarket.nsmallest(3, 'Age')

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 14))

# Bar plot for top 5 players with high market value
sns.barplot(x='Player', y='MarketValue(m)', hue='Age', data=top_5_players_high_value, ax=axes[0], palette='viridis')
axes[0].set_title('Top 5 Players with High Market Value')
axes[0].set_xlabel('Player')
axes[0].set_ylabel('Market Value (in millions)')
axes[0].legend(title='Age', bbox_to_anchor=(1.05, 1), loc='upper left')

# Bar plot for top 3 players with low age
sns.barplot(x='Player', y='MarketValue(m)', hue='Age', data=top_3_players_low_age, ax=axes[1], palette='rocket')
axes[1].set_title('Top 3 Players with Low Age and Their Market Value')
axes[1].set_xlabel('Player')
axes[1].set_ylabel('Market Value (in millions)')
axes[1].legend(title='Age', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
dfmarket[['Age','MarketValue(m)']].corr()
# Out:
#                      Age  MarketValue(m)
# Age             1.000000       -0.095878
# MarketValue(m) -0.095878        1.000000

# %% [markdown]
#  the correlation coefficient is close to zero (-0.095878), suggesting a very weak negative correlation between age and market value. The negative sign indicates that as one variable (age) increases, the other variable (market value) tends to decrease slightly, but the correlation is weak.
#
# Therefore, based on the correlation coefficient alone, we can conclude that there is a very weak negative relationship between age and market value in  dataset.

# %%
clubs_with_same_nationality_count = dfmarket.groupby('Club')['Nationality1'].nunique().reset_index(name='NumOfNationalities')

top_10_clubs = clubs_with_same_nationality_count.sort_values(by='NumOfNationalities', ascending=False).head(10)

fig = px.bar(top_10_clubs, x='NumOfNationalities', y='Club', orientation='h',
             title='Top 10 Clubs with the Highest Number of Players Sharing the Same Nationality',
             labels={'y': 'Club', 'NumOfNationalities': 'Number of Nationalities'},
             color='NumOfNationalities')

fig.show()
# Out:
# <div>                            <div id="daed5caa-de60-4fbd-8b21-47dab5160d91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daed5caa-de60-4fbd-8b21-47dab5160d91")) {                    Plotly.newPlot(                        "daed5caa-de60-4fbd-8b21-47dab5160d91",                        [{"alignmentgroup":"True","hovertemplate":"Number of Nationalities=%{marker.color}<br>Club=%{y}<extra></extra>","legendgroup":"","marker":{"color":[15,11,11,11,11,10,10,9,9,9],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15,11,11,11,11,10,10,9,9,9],"xaxis":"x","y":["Arsenal FC","Tottenham Hotspur","Liverpool FC","Manchester City","Atl\u00e9tico de Madrid","SSC Napoli","Ba
# ...

# %%
clubs_nationalities_count = dfmarket.groupby(['Club', 'Nationality1']).size().reset_index(name='PlayerCount')

most_same_nationality_club = clubs_nationalities_count.loc[clubs_nationalities_count['PlayerCount'].idxmax()]

print(f"Club with the most players of the same nationality: {most_same_nationality_club['Club']}")
print(f"Nationality: {most_same_nationality_club['Nationality1']}")
print(f"Player count: {most_same_nationality_club['PlayerCount']}")
# Out:
# Club with the most players of the same nationality: Chelsea FC
# Nationality: England
# Player count: 7

# %%
centre_forwards = dfmarket[dfmarket['Position'] == 'Centre-Forward']

print(centre_forwards[['Player', 'Position', 'Age']])
# Out:
#                Player        Position  Age
# 0      Erling Haaland  Centre-Forward   22
# 1       Kylian Mbappé  Centre-Forward   24
# 5      Victor Osimhen  Centre-Forward   24
# 16         Harry Kane  Centre-Forward   29
# 21   Lautaro Martínez  Centre-Forward   25
# ..                ...             ...  ...
# 483     Álvaro Morata  Centre-Forward   30
# 489      Mauro Icardi  Centre-Forward   30
# 490       Vitor Roque  Centre-Forward   18
# 498     Iliman Ndiaye  Centre-Forward   23
# 499           Vitinha  Centre-Forward   23
#
# [70 rows x 3 columns]

# %%
centre_forwards = dfmarket[dfmarket['Position'] == 'Centre-Forward']

# histogram with kernel density estimate
plt.figure(figsize=(10, 6))
sns.histplot(centre_forwards['Age'], bins=range(int(centre_forwards['Age'].min()), int(centre_forwards['Age'].max()) + 1),
             kde=True, color='gold')
plt.title('Age Distribution of Centre-Forward Players')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# # Age Distribution:
# The majority of Centre-Forward players fall within the age range of 17 to 35 years.
#
# # Peak Age Range:
# The peak of the density curve indicates the most common age range for Centre-Forward players.
#
# # Youthful and Experienced Players:
# The concentration of players between 17 to 35 suggests a mix of both younger, potentially emerging talents, and experienced players in this position.
#
# # Scouting and Recruitment:
# For talent scouts and recruitment strategies, focusing on players within this age range might be more fruitful, considering the density of players in this segment

# %%
import networkx as nx

G = nx.Graph()

# Add nodes for unique ages and positions
G.add_nodes_from(dfmarket['Age'].unique(), label='Age')
G.add_nodes_from(dfmarket['Position'].unique(), label='Position')

# Add edges between ages and positions
for index, row in dfmarket.iterrows():
    G.add_edge(row['Age'], row['Position'])

#  network diagram
plt.figure(figsize=(15, 10))
pos = nx.spring_layout(G)  # Layout algorithm (you can choose other layouts)
nx.draw(G, pos, with_labels=True, font_size=8, node_color='lightblue', node_size=1000, font_color='black', font_weight='bold', edge_color='gray')


plt.title('Network Diagram: Age-Position Connections', fontsize=16)

plt.show()

# %% [markdown]
# # Age-Position Relationships:
# Nodes representing age and position are connected, indicating that certain age groups are associated with specific player positions.
# For example, you might observe clusters or connections suggesting that younger players (lower age values) are more commonly associated with certain positions, while older players are associated with different positions
#
# # Position-Position Connections:
# If there are connections between different position nodes, it may suggest versatility or players transitioning between positions.
# Alternatively, it could indicate that certain positions are commonly associated with each other or share similar characteristics.
#
#
# >involving the "Centre-Forward" position having connections with defensive and midfield positions. These connections could indicate versatile players who have experience or connections with different playing roles. It might also suggest that players in the "Centre-Forward" position may occasionally play in defensive or midfield roles.

# %%
G = nx.Graph()

# nodes for unique ages, positions, and market values
G.add_nodes_from(dfmarket['Age'].unique(), label='Age')
G.add_nodes_from(dfmarket['Position'].unique(), label='Position')
G.add_nodes_from(dfmarket['MarketValue(m)'].unique(), label='MarketValue')

#  edges between ages, positions, and market values
for index, row in dfmarket.iterrows():
    G.add_edge(row['Age'], row['Position'])
    G.add_edge(row['Position'], row['MarketValue(m)'])

# a network diagram
plt.figure(figsize=(15, 10))
pos = nx.spring_layout(G)  # Layout algorithm (you can choose other layouts)
nx.draw(G, pos, with_labels=True, font_size=8, node_color='lightblue', node_size=1000, font_color='black', font_weight='bold', edge_color='gray')

plt.title('Network Diagram: Age-Position-MarketValue Connections', fontsize=16)

plt.show()

# %%
G = nx.Graph()

# nodes and edges (similar to previous examples)
G.add_nodes_from(dfmarket['Age'].unique(), label='Age')
G.add_nodes_from(dfmarket['Position'].unique(), label='Position')
G.add_nodes_from(dfmarket['MarketValue(m)'].unique(), label='MarketValue')

for index, row in dfmarket.iterrows():
    G.add_edge(row['Age'], row['Position'])
    G.add_edge(row['Position'], row['MarketValue(m)'])

#  degree centrality for each node
degree_centrality = nx.degree_centrality(G)

#  node with maximum degree centrality
max_degree_node = max(degree_centrality, key=degree_centrality.get)

# a network diagram
plt.figure(figsize=(15, 10))
pos = nx.spring_layout(G)

# nodes
nx.draw_networkx_nodes(G, pos, node_color='lightblue', node_size=1000, edgecolors='black')

#  edges
nx.draw_networkx_edges(G, pos, width=1)

# Highlight the node with maximum degree centrality
nx.draw_networkx_nodes(G, pos, nodelist=[max_degree_node], node_color='red', node_size=2000, edgecolors='black')

plt.title(f'Network Diagram with Maximum Degree Centrality ({max_degree_node}) Highlighted', fontsize=16)

plt.show()

# %%
G = nx.Graph()

G.add_nodes_from(dfmarket['Age'].unique(), label='Age')
G.add_nodes_from(dfmarket['Position'].unique(), label='Position')
G.add_nodes_from(dfmarket['MarketValue(m)'].unique(), label='MarketValue')

for index, row in dfmarket.iterrows():
    G.add_edge(row['Age'], row['Position'])
    G.add_edge(row['Position'], row['MarketValue(m)'])

degree_centrality = nx.degree_centrality(G)

max_degree_node = max(degree_centrality, key=degree_centrality.get)


print(f"Node with Maximum Degree Centrality: {max_degree_node}")
print(f"Degree Centrality: {degree_centrality[max_degree_node]}")
print(f"Connections: {list(G.neighbors(max_degree_node))}")
# Out:
# Node with Maximum Degree Centrality: Centre-Forward
# Degree Centrality: 0.6274509803921569
# Connections: [22, 180, 24, 120, 29, 90, 25, 85, 80, 26, 75, 23, 70, 65, 60, 55, 50, 48, 20, 45, 40, 27, 30, 35, 21, 32, 18, 34, 28, 19, 16, 31]

# %% [markdown]
# > Centre-Forward" position is highly connected with various ages ranging from 16 to 35 and market values ranging from 18 to 120. This suggests that players in the "Centre-Forward" position exhibit a diverse range of ages and market values in dataset
#
# > The connections with different ages might indicate that the "Centre-Forward" position is associated with players at various stages of their careers. The connections with different market values could imply that players in this position vary in terms of their market valuation
#
# >In summary, the "Centre-Forward" position in your dataset is not only associated with a diverse range of ages but also exhibits variability in market values.

# %% [markdown]
# # `Erling Haaland`

# %% [markdown]
# ![Player Image](https://img.a.transfermarkt.technology/portrait/header/418560-1694590614.jpg?lm=1)  <!-- Replace 'https://img.a.transfermarkt.technology/portrait/header/342229-1682683695.jpg?lm=1' with the actual URL of your image -->
#
# **Date of Birth/Age:** Jul 21, 2000 (23)
# **Place of Birth:** England, Leeds
# **Citizenship:** Norway
# **Height:** 1.95 m
# **Position:** Centre-Forward
# **Agent:** Rafaela Pimenta *(verified)*
# **Current International:** Norway
# **Caps/Goals:** 29 / 27

# %%
data = {'Player': ['Erling Haaland'],
        'Potential': [94.0],
        'Attacking': [76.0],
        'Skills': [70.0],
        'Movement': [82.0],
        'Power': [86.0],
        'Mentality': [75.0],
        'Defending': [42.0],
        }

df_stats = pd.DataFrame(data)


general_stats = df_stats[[ 'Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending']]

pink_color = 'deepskyblue'
spider_color = '#008080'  

fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=['General Stats', 'Spider Chart'],
    specs=[[{'type': 'bar'}], [{'type': 'scatterpolar'}]]
)

#  horizontal bar chart (General Stats)
fig.add_trace(go.Bar(
    y=general_stats.columns,
    x=general_stats.values.flatten(),
    orientation='h',
    marker=dict(color=pink_color)  # Pink color
), row=1, col=1)

#  spider chart
fig.add_trace(go.Scatterpolar(
    r=general_stats.values.flatten(),
    theta=general_stats.columns,
    fill='toself',
    marker=dict(color=spider_color),  # Teal color
), row=2, col=1)

# Update layout for better visualization
fig.update_layout(
    title_text='Erling Haaland - General Statistics and Spider Chart',
    showlegend=False,
    height=800,
    width=600,
    title_font=dict(size=20),  
    title_x=0.5,  
    title_y=0.98,  
    annotations=[{'text': 'Value', 'x': 0.5, 'y': -0.1, 'showarrow': False, 'xref': 'paper', 'yref': 'paper', 'xanchor': 'center', 'yanchor': 'bottom'}]
)


fig.show()
# Out:
# <div>                            <div id="74e09f04-6ffa-42a9-a913-2de980dcabc9" class="plotly-graph-div" style="height:800px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74e09f04-6ffa-42a9-a913-2de980dcabc9")) {                    Plotly.newPlot(                        "74e09f04-6ffa-42a9-a913-2de980dcabc9",                        [{"marker":{"color":"deepskyblue"},"orientation":"h","x":[94.0,76.0,70.0,82.0,86.0,75.0,42.0],"y":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"bar","xaxis":"x","yaxis":"y"},{"fill":"toself","marker":{"color":"#008080"},"r":[94.0,76.0,70.0,82.0,86.0,75.0,42.0],"theta":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"scatterpolar","subplot":"polar"}],                        {"template":{"
# ...

# %%
years = [2017, 2018, 2018, 2019, 2019, 2019, 2020, 2020, 2020, 2021, 2022, 2023]
market_values = [1.6, 2.4, 40, 40, 96, 360, 480, 640, 800, 1200, 1360, 1440]
ages = [16, 17, 18, 18, 19, 19, 19, 19, 20, 21, 22, 23]

# scatter plot
fig = go.Figure()

# Scatter trace
fig.add_trace(go.Scatter(
    x=years,
    y=market_values,
    mode='markers+lines',
    marker=dict(color='blue', size=20),  # Adjust the size parameter here
    line=dict(color='lightblue', width=2),
    text=ages,
    hovertemplate='Age: %{text}<br>Market Value: %{y:.0f}cr',
    showlegend=False
))


fig.update_layout(
    title='Market Value Over Years',
    xaxis_title='Year',
    yaxis_title='Market Value (in crores)',
    xaxis=dict(tickvals=years, ticktext=years),
    yaxis=dict(range=[2, 1500]),
    width=800,
    height=500
)
fig.write_html("haland.html")


fig.show()
# Out:
# <div>                            <div id="26ed7902-19d8-42c6-8e74-96b5790de5c6" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26ed7902-19d8-42c6-8e74-96b5790de5c6")) {                    Plotly.newPlot(                        "26ed7902-19d8-42c6-8e74-96b5790de5c6",                        [{"hovertemplate":"Age: %{text}<br>Market Value: %{y:.0f}cr","line":{"color":"lightblue","width":2},"marker":{"color":"blue","size":20},"mode":"markers+lines","showlegend":false,"text":["16","17","18","18","19","19","19","19","20","21","22","23"],"x":[2017,2018,2018,2019,2019,2019,2020,2020,2020,2021,2022,2023],"y":[1.6,2.4,40,40,96,360,480,640,800,1200,1360,1440],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histo
# ...

# %%
years = [2017, 2018, 2018, 2019, 2019, 2019, 2020, 2020, 2020, 2021, 2022, 2023]
market_values = [1.6, 2.4, 40, 40, 96, 360, 480, 640, 800, 1200, 1360, 1440]
ages = [16, 17, 18, 18, 19, 19, 19, 19, 20, 21, 22, 23]

# a scatter plot
fig = go.Figure()

# Scatter trace
fig.add_trace(go.Scatter(
    x=years,
    y=market_values,
    mode='markers+lines',
    marker=dict(color='blue', size=20),  # Adjust the size parameter here
    line=dict(color='lightblue', width=2),
    text=ages,
    hovertemplate='Age: %{text}<br>Market Value: %{y:.0f}cr',
    showlegend=False
))

# Layout customization
fig.update_layout(
    title='Market Value Over Years',
    xaxis_title='Year',
    yaxis_title='Market Value (in crores)',
    xaxis=dict(tickvals=years, ticktext=years),
    yaxis=dict(range=[2, 1500]),
    width=800,
    height=500
)


fig.write_html('market_value_chart.html')

# %% [markdown]
# # `Kylian Mbappe`

# %% [markdown]
# ![Player Image](https://img.a.transfermarkt.technology/portrait/header/342229-1682683695.jpg?lm=1)  <!-- Replace 'https://example.com/your_image.jpg' with the actual URL of your image -->
#
# **Date of Birth/Age:** Dec 20, 1998 (25)
# **Place of Birth:** France, Paris
# **Citizenship:** France
# **Height:** 1.78 m
# **Position:** Centre-Forward
# **Current International:** France
# **Caps/Goals:** 75 / 46

# %%
data = {'Player': ['Kylian Mbappé'],
        'Potential': [94.0],
        'Attacking': [82.0],
        'Skills': [81.0],
        'Movement': [92.0],
        'Power': [82.0],
        'Mentality': [74.0],
        'Defending': [31.0],
        }

df_stats = pd.DataFrame(data)

#  general statistics
general_stats = df_stats[[ 'Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending']]


pink_color = 'darkblue'
spider_color = '#008080'  # Teal color for spider chart


fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=['General Stats', 'Spider Chart'],
    specs=[[{'type': 'bar'}], [{'type': 'scatterpolar'}]]
)

#  horizontal bar chart (General Stats)
fig.add_trace(go.Bar(
    y=general_stats.columns,
    x=general_stats.values.flatten(),
    orientation='h',
    marker=dict(color=pink_color)  # Pink color
), row=1, col=1)

#  spider chart
fig.add_trace(go.Scatterpolar(
    r=general_stats.values.flatten(),
    theta=general_stats.columns,
    fill='toself',
    marker=dict(color=spider_color),  # Teal color
), row=2, col=1)

fig.update_layout(
    title_text='Kylian Mbappé - General Statistics and Spider Chart',
    showlegend=False,
    height=800,
    width=600,
    title_font=dict(size=20), 
    title_x=0.5,  
    title_y=0.98,  
    annotations=[{'text': 'Value', 'x': 0.5, 'y': -0.1, 'showarrow': False, 'xref': 'paper', 'yref': 'paper', 'xanchor': 'center', 'yanchor': 'bottom'}]
)


fig.show()
# Out:
# <div>                            <div id="ba8bd9bc-138b-4f39-8180-359ede58f324" class="plotly-graph-div" style="height:800px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba8bd9bc-138b-4f39-8180-359ede58f324")) {                    Plotly.newPlot(                        "ba8bd9bc-138b-4f39-8180-359ede58f324",                        [{"marker":{"color":"darkblue"},"orientation":"h","x":[94.0,82.0,81.0,92.0,82.0,74.0,31.0],"y":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"bar","xaxis":"x","yaxis":"y"},{"fill":"toself","marker":{"color":"#008080"},"r":[94.0,82.0,81.0,92.0,82.0,74.0,31.0],"theta":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"scatterpolar","subplot":"polar"}],                        {"template":{"dat
# ...

# %%
years = [2015, 2016, 2016, 2017, 2017, 2018, 2018, 2018, 2020, 2021, 2022, 2023]
market_values = [40, 8, 32, 280, 720, 960, 1200, 1600, 1400, 1280, 1440, 1440]
ages = [16, 17, 17, 18, 18, 19, 19, 19, 21, 22, 24, 24]

#   scatter plot
fig = go.Figure()

# Scatter trace
fig.add_trace(go.Scatter(
    x=years,
    y=market_values,
    mode='markers+lines',
    marker=dict(color='darkblue', size=20),  
    line=dict(color='lightblue', width=2),
    text=ages,
    hovertemplate='Age: %{text}<br>Market Value: %{y:.0f}cr',
    showlegend=False
))


fig.update_layout(
    title='Market Value Over Years',
    xaxis_title='Year',
    yaxis_title='Market Value (in crores)',
    xaxis=dict(tickvals=years, ticktext=years),
    yaxis=dict(range=[2, 1500]),
    width=800,
    height=500
)
fig.write_html("mbappe.html")


fig.show()
# Out:
# <div>                            <div id="b225beef-e964-46be-9b00-ffb2ecb6ad61" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b225beef-e964-46be-9b00-ffb2ecb6ad61")) {                    Plotly.newPlot(                        "b225beef-e964-46be-9b00-ffb2ecb6ad61",                        [{"hovertemplate":"Age: %{text}<br>Market Value: %{y:.0f}cr","line":{"color":"lightblue","width":2},"marker":{"color":"darkblue","size":20},"mode":"markers+lines","showlegend":false,"text":["16","17","17","18","18","19","19","19","21","22","24","24"],"x":[2015,2016,2016,2017,2017,2018,2018,2018,2020,2021,2022,2023],"y":[40,8,32,280,720,960,1200,1600,1400,1280,1440,1440],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":
# ...

# %%
correlation_matrix = df_analysis[['Skills', 'MarketValue(m)']].corr()

skills_market_value_corr = correlation_matrix.loc['Skills', 'MarketValue(m)']

print(f'Correlation between Skills and Market Value: {skills_market_value_corr}')
# Out:
# Correlation between Skills and Market Value: 0.2068207908638127

# %% [markdown]
# A correlation coefficient of 0.207 suggests a relatively weak positive correlation between the 'Skills' and 'MarketValue(m)' columns in your dataset. This means that as the value of the 'Skills' column increases, there is a tendency for the 'MarketValue(m)' to also increase, but the relationship is not very strong.
#
#
#
# In practical terms, it implies that there is some association between a player's skills and their market value, but other factors may also contribute to determining market value.

# %% [markdown]
# # Clubs with Highest Market Value Players

# %%
df_sorted = dfmarket.sort_values(by='MarketValue(m)', ascending=False)

# Select the top 10 clubs
top_10_clubs = df_sorted.head(10)

# Plot the bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='MarketValue(m)', y='Club', data=top_10_clubs, palette='viridis')
plt.title('Top Clubs with Highest Market Value Players')
plt.xlabel('Market Value (m)')
plt.ylabel('Club')
plt.show()

# %% [markdown]
# # 2. identify undervalued players

# %%
from fuzzywuzzy import process

# Function to find the best match for a player in the market DataFrame
def find_best_match(player_name, market_players):
    return process.extractOne(player_name, market_players)

# Create a mapping between players in dfplayer and their best match in dfmarket
dfplayer['Best_Match'] = dfplayer['Player'].apply(lambda x: find_best_match(x, dfmarket['Player']))
dfplayer['Best_Match_Player'] = dfplayer['Best_Match'].apply(lambda x: x[0] if x else None)
dfplayer['Match_Score'] = dfplayer['Best_Match'].apply(lambda x: x[1] if x else None)

# Filter rows where the match score is above a certain threshold (adjust as needed)
threshold = 80
dfplayer_filtered = dfplayer[dfplayer['Match_Score'] >= threshold]

# Merge based on the best-matched player
merged_df = pd.merge(dfplayer_filtered, dfmarket, left_on='Best_Match_Player', right_on='Player', how='inner')

# Selecting relevant columns for analysis
selected_columns = ['Player_x', 'Overall', 'Potential', 'Attacking', 'Skills', 'Movement', 'Power',
                    'Mentality', 'Defending', 'Goalkeeping', 'STATS', 'MarketValue(m)']
df_analysis = merged_df[selected_columns].rename(columns={'Player_x': 'Player'})

# %%
print(df_analysis.columns)
# Out:
# Index(['Player', 'Overall', 'Potential', 'Attacking', 'Skills', 'Movement',
#        'Power', 'Mentality', 'Defending', 'Goalkeeping', 'STATS',
#        'MarketValue(m)'],
#       dtype='object')

# %%
df_analysis.drop("Goalkeeping",axis=1,inplace=True)

# %%
df_analysis.head()
# Out:
#               Player  Overall  Potential  Attacking  Skills  Movement  Power  \
# 0    Kylian MbappéST     91.0       94.0       82.0    81.0      92.0   82.0
# 1   Erling HaalandST     91.0       94.0       76.0    70.0      82.0   86.0
# 2  Kevin De BruyneCM     91.0       91.0       82.0    89.0      79.0   82.0
# 3    Lionel MessiCAM     90.0       90.0       85.0    93.0      88.0   77.0
# 4    Karim BenzemaCF     90.0       90.0       87.0    82.0      80.0   82.0
#
#    Mentality  Defending  STATS  MarketValue(m)
# 0       74.0       31.0  2,204             180
# 1       75.0       42.0  2,156             180
# 2       83.0       62.0  2,317              70
# 3       74.0       26.0  2,166              35
# 4       76.0       28.0  2,152              25

# %%
threshold_ratio = 0.01
undervalued_players = df_analysis[df_analysis['Overall'] / df_analysis['MarketValue(m)'] > threshold_ratio]

# Convert 'Overall' and 'MarketValue(m)' columns to numeric
undervalued_players['Overall'] = pd.to_numeric(undervalued_players['Overall'])
undervalued_players['MarketValue(m)'] = pd.to_numeric(undervalued_players['MarketValue(m)'])

# Calculate the Performance-to-Market-Value Ratio for undervalued players
undervalued_players['PerformanceRatio'] = undervalued_players['Overall'] / undervalued_players['MarketValue(m)']

top_10_undervalued_players = undervalued_players.nlargest(10, 'PerformanceRatio')

print(top_10_undervalued_players[['Player', 'Overall', 'MarketValue(m)', 'PerformanceRatio']])
# Out:
#                Player  Overall  MarketValue(m)  PerformanceRatio
# 17          EdersonGK     88.0              20          4.400000
# 41     Riyad MahrezRW     85.0              20          4.250000
# 34       M. de LigtCB     86.0              22          3.909091
# 4     Karim BenzemaCF     90.0              25          3.600000
# 40       Sadio ManéLM     86.0              25          3.440000
# 52  Aymeric LaporteCB     85.0              25          3.400000
# 38    Paulo DybalaCAM     86.0              30          2.866667
# 3     Lionel MessiCAM     90.0              35          2.571429
# 10  Virgil van DijkCB     89.0              35          2.542857
# 11          AlissonGK     89.0              35          2.542857

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Overall', y='MarketValue(m)', hue='Overall', data=df_analysis, palette='viridis')
plt.title('Player Overall Rating vs. Market Value (Color-coded by Overall Rating)')
plt.show()

# %%
threshold_ratio = 0.01

# Filter undervalued players
undervalued_players = df_analysis[df_analysis['Overall'] / df_analysis['MarketValue(m)'] > threshold_ratio]

# Convert 'Overall' and 'MarketValue(m)' columns to numeric
undervalued_players['Overall'] = pd.to_numeric(undervalued_players['Overall'])
undervalued_players['MarketValue(m)'] = pd.to_numeric(undervalued_players['MarketValue(m)'])

# Calculate the performance-to-market-value ratio
undervalued_players['PerformanceRatio'] = undervalued_players['Overall'] / undervalued_players['MarketValue(m)']

# Sort undervalued players by their performance-to-market-value ratio
undervalued_players = undervalued_players.sort_values(by='PerformanceRatio', ascending=False)

top_20_undervalued_players = undervalued_players.head(20)


custom_colors = ['#E5AF0A', '#BC8901', '#745305', '#5F4509', '#E6E6E6',
                '#C8C7C7', '#ABA7A8', '#787374', '#50494A']

plt.figure(figsize=(12, 8))
sns.barplot(x='PerformanceRatio', y='Player', data=top_20_undervalued_players, palette=custom_colors)

plt.title('Top 20 Undervalued Players with Good Statistics (Sorted by Performance-to-Market-Value Ratio)')
plt.xlabel('Performance-to-Market-Value Ratio')
plt.ylabel('Player')
plt.show()

# %% [markdown]
# ##  General stats Undervalued Players & stats across different competitions

# %% [markdown]
# 1. Lionel Messi
#
# 2. Neymar Jr
#
# 3. Karim Benzema

# %% [markdown]
# ## `Lionel Messi`

# %% [markdown]
# ![Player Image](https://img.a.transfermarkt.technology/portrait/header/28003-1694590254.jpg?lm=1)  <!-- Replace 'https://example.com/your_image.jpg' with the actual URL of your image -->
#
# **Date of Birth/Age:** Jun 24, 1987 (36)
# **Place of Birth:** Argentina, Rosario
# **Citizenship:** Argentina
# **Height:** 1.70 m
# **Position:** Right Winger
# **Current International:** Argentina
# **Caps/Goals:** 180 / 106

# %%
messi_data = df_analysis[df_analysis['Player'] == 'Lionel MessiCAM']

# Convert 'Overall' and 'MarketValue(m)' columns to numeric
messi_data['Overall'] = pd.to_numeric(messi_data['Overall'])
messi_data['MarketValue(m)'] = pd.to_numeric(messi_data['MarketValue(m)'])

# Calculate the Performance-to-Market-Value Ratio for Messi
messi_data['PerformanceRatio'] = messi_data['Overall'] / messi_data['MarketValue(m)']

print(messi_data[['Player', 'Overall', 'MarketValue(m)', 'PerformanceRatio']])
# Out:
#             Player  Overall  MarketValue(m)  PerformanceRatio
# 3  Lionel MessiCAM     90.0              35          2.571429

# %% [markdown]
# In simple terms, while Messi has a high 'Overall' rating (indicating high performance), the 'MarketValue(m)' assigned to him is also high. As a result, the ratio of 'Overall' to 'MarketValue(m)' is lower compared to other players who might have a lower market value for a similar or slightly lower performance.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Data for Lionel Messi
data = {'Player': ['Lionel MessiCAM'],
        'Potential': [90.0],
        'Attacking': [85.0],
        'Skills': [93.0],
        'Movement': [88.0],
        'Power': [77.0],
        'Mentality': [74.0],
        'Defending': [26.0],}
      

df_stats = pd.DataFrame(data)

general_stats = df_stats[[ 'Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending']]


pink_color = '#FF1493'
spider_color = '#008080'  

fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=['General Stats', 'Spider Chart'],
    specs=[[{'type': 'bar'}], [{'type': 'scatterpolar'}]]
)

fig.add_trace(go.Bar(
    y=general_stats.columns,
    x=general_stats.values.flatten(),
    orientation='h',
    marker=dict(color=pink_color)  # Pink color
), row=1, col=1)

#  spider chart
fig.add_trace(go.Scatterpolar(
    r=general_stats.values.flatten(),
    theta=general_stats.columns,
    fill='toself',
    marker=dict(color=spider_color),  # Teal color
), row=2, col=1)


fig.update_layout(
    title_text='Lionel Messi - General Statistics and Spider Chart',
    showlegend=False,
    height=800,
    width=600,
    title_font=dict(size=20),  
    title_x=0.5,  
    title_y=0.98,  
    annotations=[{'text': 'Value', 'x': 0.5, 'y': -0.1, 'showarrow': False, 'xref': 'paper', 'yref': 'paper', 'xanchor': 'center', 'yanchor': 'bottom'}]
)


fig.show()
# Out:
# <div>                            <div id="ce7b6cd9-7128-4e4e-b6ac-9c44752a754a" class="plotly-graph-div" style="height:800px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce7b6cd9-7128-4e4e-b6ac-9c44752a754a")) {                    Plotly.newPlot(                        "ce7b6cd9-7128-4e4e-b6ac-9c44752a754a",                        [{"marker":{"color":"#FF1493"},"orientation":"h","x":[90.0,85.0,93.0,88.0,77.0,74.0,26.0],"y":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"bar","xaxis":"x","yaxis":"y"},{"fill":"toself","marker":{"color":"#008080"},"r":[90.0,85.0,93.0,88.0,77.0,74.0,26.0],"theta":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"scatterpolar","subplot":"polar"}],                        {"template":{"data
# ...

# %% [markdown]
# # ` Neymar Jr`

# %% [markdown]
# ![Player Image](https://img.a.transfermarkt.technology/portrait/header/68290-1697056482.png?lm=1)  <!-- Replace 'https://example.com/your_image.jpg' with the actual URL of your image -->
#
# **Date of Birth/Age:** Jun 24, 1987 (36)
# **Place of Birth:** Argentina, Rosario
# **Citizenship:** Argentina
# **Height:** 1.70 m
# **Position:** Right Winger
# **Current International:** Argentina
# **Caps/Goals:** 180 / 106

# %%
data = {'Player': ['Neymar Jr'],
        'Potential': [89.0],
        'Attacking': [80.0],
        'Skills': [89.0],
        'Movement': [87.0],
        'Power': [71.0],
        'Mentality': [77.0],
        'Defending': [32.0],
        }

df_stats = pd.DataFrame(data)


general_stats = df_stats[[ 'Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending']]

pink_color = 'light blue'
spider_color = '#008080'  


fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=['General Stats', 'Spider Chart'],
    specs=[[{'type': 'bar'}], [{'type': 'scatterpolar'}]]
)

#  horizontal bar chart (General Stats)
fig.add_trace(go.Bar(
    y=general_stats.columns,
    x=general_stats.values.flatten(),
    orientation='h',
    marker=dict(color=pink_color)  # Pink color
), row=1, col=1)

#  spider chart
fig.add_trace(go.Scatterpolar(
    r=general_stats.values.flatten(),
    theta=general_stats.columns,
    fill='toself',
    marker=dict(color=spider_color), 
), row=2, col=1)

fig.update_layout(
    title_text='Neymar Jr - General Statistics and Spider Chart',
    showlegend=False,
    height=800,
    width=600,
    title_font=dict(size=20),  
    title_x=0.5,  
    title_y=0.98, 
    annotations=[{'text': 'Value', 'x': 0.5, 'y': -0.1, 'showarrow': False, 'xref': 'paper', 'yref': 'paper', 'xanchor': 'center', 'yanchor': 'bottom'}]
)


fig.show()
# Out:
# <div>                            <div id="1d00d5dc-9b98-467b-8960-d6676afe9e44" class="plotly-graph-div" style="height:800px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d00d5dc-9b98-467b-8960-d6676afe9e44")) {                    Plotly.newPlot(                        "1d00d5dc-9b98-467b-8960-d6676afe9e44",                        [{"marker":{"color":"light blue"},"orientation":"h","x":[89.0,80.0,89.0,87.0,71.0,77.0,32.0],"y":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"bar","xaxis":"x","yaxis":"y"},{"fill":"toself","marker":{"color":"#008080"},"r":[89.0,80.0,89.0,87.0,71.0,77.0,32.0],"theta":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"scatterpolar","subplot":"polar"}],                        {"template":{"d
# ...

# %% [markdown]
# # `Karim Benzema`

# %% [markdown]
# ![Player Image](https://img.a.transfermarkt.technology/portrait/header/18922-1702414196.jpg?lm=1)  <!-- Replace 'https://example.com/your_image.jpg' with the actual URL of your image -->
#
# **Date of Birth/Age:** Jun 24, 1987 (36)
# **Place of Birth:** Argentina, Rosario
# **Citizenship:** Argentina
# **Height:** 1.70 m
# **Position:** Right Winger
# **Current International:** Argentina
# **Caps/Goals:** 180 / 106

# %%
data = {'Player': ['Karim Benzema'],  
        'Potential': [90.0],
        'Attacking': [87.0],
        'Skills': [82.0],
        'Movement': [80.0],
        'Power': [82.0],
        'Mentality': [76.0],
        'Defending': [28.0],
        }

df_stats = pd.DataFrame(data)


general_stats = df_stats[[ 'Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending']]

pink_color = 'yellow'
spider_color = '#008080'  


fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=['General Stats', 'Spider Chart'],
    specs=[[{'type': 'bar'}], [{'type': 'scatterpolar'}]]
)

#  horizontal bar chart (General Stats)
fig.add_trace(go.Bar(
    y=general_stats.columns,
    x=general_stats.values.flatten(),
    orientation='h',
    marker=dict(color=pink_color)  
), row=1, col=1)

#  spider chart
fig.add_trace(go.Scatterpolar(
    r=general_stats.values.flatten(),
    theta=general_stats.columns,
    fill='toself',
    marker=dict(color=spider_color),  
), row=2, col=1)

fig.update_layout(
    title_text='Karim Benzema - General Statistics and Spider Chart',
    showlegend=False,
    height=800,
    width=600,
    title_font=dict(size=20), 
    title_x=0.5,  
    title_y=0.98,  
    annotations=[{'text': 'Value', 'x': 0.5, 'y': -0.1, 'showarrow': False, 'xref': 'paper', 'yref': 'paper', 'xanchor': 'center', 'yanchor': 'bottom'}]
)


fig.show()
# Out:
# <div>                            <div id="5ed95e8a-4d18-4cc4-9b9f-43983e6c355a" class="plotly-graph-div" style="height:800px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ed95e8a-4d18-4cc4-9b9f-43983e6c355a")) {                    Plotly.newPlot(                        "5ed95e8a-4d18-4cc4-9b9f-43983e6c355a",                        [{"marker":{"color":"yellow"},"orientation":"h","x":[90.0,87.0,82.0,80.0,82.0,76.0,28.0],"y":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"bar","xaxis":"x","yaxis":"y"},{"fill":"toself","marker":{"color":"#008080"},"r":[90.0,87.0,82.0,80.0,82.0,76.0,28.0],"theta":["Potential","Attacking","Skills","Movement","Power","Mentality","Defending"],"type":"scatterpolar","subplot":"polar"}],                        {"template":{"data"
# ...

# %%
dfmarket.head()
# Out:
#             Player          Position  Age Nationality1 Nationality2  \
# 0   Erling Haaland    Centre-Forward   22       Norway          NaN
# 1    Kylian Mbappé    Centre-Forward   24       France     Cameroon
# 2  Vinicius Junior       Left Winger   22       Brazil        Spain
# 3  Jude Bellingham  Central Midfield   20      England          NaN
# 4      Bukayo Saka      Right Winger   21      England      Nigeria
#
#                   Club  MarketValue(m)
# 0      Manchester City             180
# 1  Paris Saint-Germain             180
# 2          Real Madrid             150
# 3          Real Madrid             120
# 4           Arsenal FC             120

# %% [markdown]
# # 3.Quantifying the Impact of Age and Position on Football Player Market Value.

# %% [markdown]
# ## Market value of years

# %% [markdown]
# 1. # `Cristiano Ronaldo`

# %% [markdown]
# ![New Player Image](https://img.a.transfermarkt.technology/portrait/header/8198-1694609670.jpg?lm=1)  <!-- Replace 'https://example.com/new_player_image.jpg' with the actual URL of the new player's image -->
#
# **Date of Birth/Age:** Feb 5, 1985 (39)
# **Place of Birth:** Portugal, Funchal
# **Citizenship:** Portugal
# **Height:** 1.87 m
# **Position:** Centre-Forward
# **Agent:** Gestifute (Verified)
# **Current International:** Portugal
# **Caps/Goals:** 205 / 128

# %%
# Data for Cristiano Ronaldo
years = [2004,2005,2006,2008,2009,2010,2012,2012,2014,2014,2015,2017,2018,2018,2020,2021,2021,2022,2023]
market_values = [144,212,272,440,560,720,720,800,800,960,880,800,960,800,480,360,280,160,120]
ages = [19,20,22,23,24,25,26,27,29,29,30,31,32,33,35,36,36,37,38]


fig = go.Figure()

fig.add_trace(go.Scatter(
    x=ages,
    y=market_values,
    mode='markers+lines',
    marker=dict(color='blue', size=10),
    line=dict(color='lightblue', width=2),
    text=years,
    hovertemplate='Year: %{text}<br>Age: %{x}<br>Market Value: %{y}cr',
    showlegend=False
))

#  trendline
fig.add_trace(go.Scatter(
    x=ages,
    y=market_values,
    mode='lines',
    line=dict(color='yellow', width=2),
    name='Trendline'
))


fig.update_layout(
    title='Cristiano Ronaldo - Age vs. Market Value',
    xaxis_title='Age',
    yaxis_title='Market Value (in crores)',
    template='plotly_white'
)


fig.write_html("ronaldo.html")
fig.show()
# Out:
# <div>                            <div id="82bdfc14-c428-4098-980a-efe3d1f59b63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82bdfc14-c428-4098-980a-efe3d1f59b63")) {                    Plotly.newPlot(                        "82bdfc14-c428-4098-980a-efe3d1f59b63",                        [{"hovertemplate":"Year: %{text}<br>Age: %{x}<br>Market Value: %{y}cr","line":{"color":"lightblue","width":2},"marker":{"color":"blue","size":10},"mode":"markers+lines","showlegend":false,"text":["2004","2005","2006","2008","2009","2010","2012","2012","2014","2014","2015","2017","2018","2018","2020","2021","2021","2022","2023"],"x":[19,20,22,23,24,25,26,27,29,29,30,31,32,33,35,36,36,37,38],"y":[144,212,272,440,560,720,720,800,800,960,880,800,960,800,480,360,280,16
# ...

# %%
correlation_coefficient = np.corrcoef(ages, market_values)[0, 1]

print(f'Correlation between Market Value and Age: {correlation_coefficient:.4f}')
# Out:
# Correlation between Market Value and Age: 0.0126

# %% [markdown]
# The correlation coefficient between market value and age for the provided data on Cristiano Ronaldo is approximately 0.0126. This value is close to zero, indicating a very weak or negligible linear relationship between market value and age in the given dataset.
#
# In practical terms, this means that there is no strong linear trend suggesting that as age increases, market value consistently increases or decreases. Other factors or non-linear relationships might be influencing market value in this context

# %% [markdown]
# # 2. `Lionel Messi`

# %% [markdown]
# ![Player Image](https://img.a.transfermarkt.technology/portrait/header/28003-1694590254.jpg?lm=1)  <!-- Replace 'https://example.com/your_image.jpg' with the actual URL of your image -->
#
# **Date of Birth/Age:** Jun 24, 1987 (36)
# **Place of Birth:** Argentina, Rosario
# **Citizenship:** Argentina
# **Height:** 1.70 m
# **Position:** Right Winger
# **Current International:** Argentina
# **Caps/Goals:** 180 / 106

# %%
years = [2004,2005,2007,2007,2008,2009,2009,2010,2010,2012,2012,2013,2014,2016,2017,2018,2018,2020,2021,2022,2023]
market_values = [24,40,320,480,440,480,560,640,800,800,960,960,960,960,960,1440,1280,896,640,400,280]
ages = [17,18,20,20,21,21,22,22,23,24,25,25,27,29,29,30,31,32,33,34,36]

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=ages,
    y=market_values,
    mode='markers+lines',
    marker=dict(color='black', size=10),
    line=dict(color='lightblue', width=2),
    text=years,
    hovertemplate='Year: %{text}<br>Age: %{x}<br>Market Value: %{y}cr',
    showlegend=False
))


fig.add_trace(go.Scatter(
    x=ages,
    y=market_values,
    mode='lines',
    line=dict(color='pink', width=2),
    name='Trendline'
))


fig.update_layout(
    title='Lionel Messi - Age vs. Market Value',
    xaxis_title='Age',
    yaxis_title='Market Value (in crores)',
    template='plotly_white'
)


fig.write_html("messi.html")

fig.show()
# Out:
# <div>                            <div id="edd70567-ab35-47f6-bd82-4ed42d4480fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edd70567-ab35-47f6-bd82-4ed42d4480fe")) {                    Plotly.newPlot(                        "edd70567-ab35-47f6-bd82-4ed42d4480fe",                        [{"hovertemplate":"Year: %{text}<br>Age: %{x}<br>Market Value: %{y}cr","line":{"color":"lightblue","width":2},"marker":{"color":"black","size":10},"mode":"markers+lines","showlegend":false,"text":["2004","2005","2007","2007","2008","2009","2009","2010","2010","2012","2012","2013","2014","2016","2017","2018","2018","2020","2021","2022","2023"],"x":[17,18,20,20,21,21,22,22,23,24,25,25,27,29,29,30,31,32,33,34,36],"y":[24,40,320,480,440,480,560,640,800,800,960,960,960
# ...

# %%
correlation_coefficient = np.corrcoef(ages, market_values)[0, 1]


print(f'Correlation between Market Value and Age: {correlation_coefficient:.4f}')
# Out:
# Correlation between Market Value and Age: 0.4548

# %% [markdown]
# # which factor market value dcerese

# %%
correlation = df_analysis[['Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending', 'MarketValue(m)']].corr()['MarketValue(m)']
correlation
# Out:
# Potential         0.632409
# Attacking         0.268658
# Skills            0.206821
# Movement          0.360352
# Power             0.210752
# Mentality         0.242135
# Defending        -0.015767
# MarketValue(m)    1.000000
# Name: MarketValue(m), dtype: float64

# %%
correlation_values = correlation[:-1]

sns.set_palette("YlOrBr")

plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_values.index, y=correlation_values.values)
plt.title('Correlation with Market Value')
plt.xlabel('Attributes')
plt.ylabel('Correlation')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The attribute that shows a negative correlation with Market Value is "Defending" with a correlation coefficient of approximately -0.016. This suggests that a higher emphasis on Defending attributes may lead to a decrease in Market Value.
#
# Other attributes like Potential, Attacking, Skills, Movement, Power, and Mentality show positive correlations with Market Value, indicating that an increase in these attributes generally leads to higher Market Values for players.

# %%
attributes = ['Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending']

plt.figure(figsize=(12, 10))

for i, attribute in enumerate(attributes):
    plt.subplot(3, 3, i+1)
    plt.scatter(df_analysis[attribute], df_analysis['MarketValue(m)'], alpha=0.5, color='purple')
    plt.title(f'{attribute} vs. Market Value')
    plt.xlabel(attribute)
    plt.ylabel('Market Value (m)')

plt.tight_layout()
plt.show()

# %%
numeric_cols = ['Overall', 'Potential', 'Attacking', 'Skills', 'Movement', 'Power', 'Mentality', 'Defending', 'MarketValue(m)']
correlation_matrix = df_analysis[numeric_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='crest', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Player Attributes')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='Player', y='MarketValue(m)', data=df_analysis, color='purple')
plt.xticks(rotation=45)
plt.title('Market Value Trend with Players')
plt.xlabel('Player')
plt.ylabel('Market Value (m)')
plt.show()

# %% [markdown]
# This line plot illustrates the pattern and trend in Market Value across different players. You can see how the Market Value varies for each player, providing insights into the distribution and trends within the dataset.

# %% [markdown]
# # Average Market Value by Position

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Overall', y='MarketValue(m)', data=df_analysis)
plt.title('Average Market Value by Position')
plt.xlabel('Overall')
plt.ylabel('Market Value (m)')
plt.show()

# %%
# Count the occurrences of each position
position_counts = dfmarket['Position'].value_counts()

# Create a circular bar plot
theta = np.linspace(0.0, 2 * np.pi, len(position_counts), endpoint=False)
width = (2 * np.pi) / len(position_counts)

plt.figure(figsize=(10, 10))
ax = plt.subplot(111, polar=True)
bars = ax.bar(theta, position_counts, width=width, color='skyblue')

# Labeling each bar with the position names
ax.set_xticks(theta)
ax.set_xticklabels(position_counts.index)

plt.title('Circular Bar Plot of Player Positions')
plt.show()

# %%
import matplotlib.pyplot as plt

x_values = [0, 10, 20, 30, 40, 50, 60, 70]
goalkeeper_data = [2, 4, 6, 8, 10, 8, 6, 4]
defender_data = [0, 2, 5, 7, 9, 7, 5, 3]
midfielder_data = [1, 3, 7, 9, 10, 8, 5, 2]
forward_data = [3, 5, 8, 10, 8, 6, 4, 2]

plt.bar(x_values, goalkeeper_data, width=8, label='Goalkeeper')
plt.bar(x_values, defender_data, width=8, label='Defender', bottom=goalkeeper_data)
plt.bar(x_values, midfielder_data, width=8, label='Midfielder', bottom=[i+j for i,j in zip(goalkeeper_data, defender_data)])
plt.bar(x_values, forward_data, width=8, label='Forward', bottom=[i+j+k for i,j,k in zip(goalkeeper_data, defender_data, midfielder_data)])

plt.xlabel('X-axis')
plt.ylabel('Number of Players')
plt.title('Number of Players in Each Position')
plt.legend()

plt.show()
